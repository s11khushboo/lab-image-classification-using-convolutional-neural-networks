# %% [markdown]
# # Lab : Image Classification using Convolutional Neural Networks
#
# At the end of this laboratory, you would get familiarized with
#
# *   Creating deep networks using Keras
# *   Steps necessary in training a neural network
# *   Prediction and performance analysis using neural networks
#
# ---

# %% [markdown]
# # **In case you use a colaboratory environment**
# By default, Colab notebooks run on CPU.
# You can switch your notebook to run with GPU.
#
# In order to obtain access to the GPU, you need to choose the tab Runtime and then select “Change runtime type” as shown in the following figure:
#
# ![Changing runtime](https://miro.medium.com/max/747/1*euE7nGZ0uJQcgvkpgvkoQg.png)
#
# When a pop-up window appears select GPU. Ensure “Hardware accelerator” is set to GPU.

# %% [markdown]
# # **Working with a new dataset: CIFAR-10**
#
# The CIFAR-10 dataset consists of 60000 32x32 colour images in 10 classes, with 6000 images per class. There are 50000 training images and 10000 test images. More information about CIFAR-10 can be found [here](https://www.cs.toronto.edu/~kriz/cifar.html).
#
# In Keras, the CIFAR-10 dataset is also preloaded in the form of four Numpy arrays. x_train and y_train contain the training set, while x_test and y_test contain the test data. The images are encoded as Numpy arrays and their corresponding labels ranging from 0 to 9.
#
# Your task is to:
#
# *   Visualize the images in CIFAR-10 dataset. Create a 10 x 10 plot showing 10 random samples from each class.
# *   Convert the labels to one-hot encoded form.
# *   Normalize the images.

# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.datasets import cifar10
from keras.utils import to_categorical

# Load CIFAR-10 dataset
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 108s 1us/step

# %%
from matplotlib import image
from matplotlib import pyplot
fig, axes = plt.subplots(10, 10, figsize=(15, 15))
fig.subplots_adjust(hspace=0.5, wspace=0.5)

for class_idx in range(10):
    # Find all indices for the current class
    class_indices = np.where(y_train.flatten() == class_idx)[0]
    # Pick 10 random samples from this class
    random_indices = np.random.choice(class_indices, 10, replace=False)

    for i, img_idx in enumerate(random_indices):
        ax = axes[class_idx, i]
        ax.imshow(x_train[img_idx])
        ax.axis('off')


plt.show()

x_train = x_train.astype("float32")/255.0
x_test = x_test.astype("float32")/255.0
print("x_train shape:", x_train.shape)


y_train = y_train.flatten()
y_test = y_test.flatten()
y_train_onehot = to_categorical(y_train, num_classes=10)
y_test_onehot = to_categorical(y_test, num_classes=10)
print(x_train.shape, y_train_onehot.shape)
# Out:
# x_train shape: (50000, 32, 32, 3)
# (50000, 32, 32, 3) (50000, 10)

# %% [markdown]
# ## Define the following model (same as the one in tutorial)
#
# For the convolutional front-end, start with a single convolutional layer with a small filter size (3,3) and a modest number of filters (32) followed by a max pooling layer.
#
# Use the input as (32,32,3).
#
# The filter maps can then be flattened to provide features to the classifier.
#
# Use a dense layer with 100 units before the classification layer (which is also a dense layer with softmax activation).

# %%
from keras.backend import clear_session
clear_session()
from keras import Sequential
from keras import layers
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential([
    layers.Input(shape=(32, 32, 3)),
    layers.Conv2D(32, kernel_size=(3, 3), activation='relu'),
    layers.MaxPooling2D(pool_size=(2, 2)),
    layers.Flatten(),
    layers.Dense(100, activation='relu'),
    layers.Dense(10, activation='softmax')
])

# %% [markdown]
# *   Compile the model using categorical_crossentropy loss, SGD optimizer and use 'accuracy' as the metric.
# *   Use the above defined model to train CIFAR-10 and train the model for 50 epochs with a batch size of 512.

# %%
from keras.optimizers import SGD
model.compile(
    optimizer=SGD(),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)
history = model.fit(
    x_train, y_train_onehot,
    epochs=50,
    batch_size=512,
    validation_split=0.2
)
# Out:
# Epoch 1/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 47ms/step - accuracy: 0.1462 - loss: 2.2860 - val_accuracy: 0.2074 - val_loss: 2.2240
# Epoch 2/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.2285 - loss: 2.1968 - val_accuracy: 0.2308 - val_loss: 2.1300
# Epoch 3/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.2681 - loss: 2.0932 - val_accuracy: 0.2656 - val_loss: 2.0402
# Epoch 4/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.3009 - loss: 2.0070 - val_accuracy: 0.2843 - val_loss: 2.0179
# Epoch 5/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.3191 - loss: 1.9523 - val_accuracy: 0.3119 - val_loss: 1.9518
# Epoch 6/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.3336 - loss: 1.9160 - val_accuracy: 0.3031 - val_loss: 1.9335
# Epoch 7/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.3454 - loss: 1.8789 - val_accuracy: 0.3302 - val_loss: 1.8912
# Epoch 8/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.3557 - loss: 1.8549 - val_accuracy: 0.3268 - val_loss: 1.9094
# Epoch 9/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.3613 - loss: 1.8374 - val_accuracy: 0.3488 - val_loss: 1.8503
# Epoch 10/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.3717 - loss: 1.8163 - val_accuracy: 0.3520 - val_loss: 1.8370
# Epoch 11/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.3795 - loss: 1.7947 - val_accuracy: 0.3492 - val_loss: 1.8629
# Epoch 12/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.3831 - loss: 1.7731 - val_accuracy: 0.3537 - val_loss: 1.8505
# Epoch 13/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.3909 - loss: 1.7594 - val_accuracy: 0.3860 - val_loss: 1.7686
# Epoch 14/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.4030 - loss: 1.7268 - val_accuracy: 0.3540 - val_loss: 1.8069
# Epoch 15/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.4110 - loss: 1.7111 - val_accuracy: 0.3723 - val_loss: 1.8235
# Epoch 16/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.4061 - loss: 1.7043 - val_accuracy: 0.3931 - val_loss: 1.7349
# Epoch 17/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.4135 - loss: 1.6834 - val_accuracy: 0.3959 - val_loss: 1.7107
# Epoch 18/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.4244 - loss: 1.6620 - val_accuracy: 0.3531 - val_loss: 1.7573
# Epoch 19/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.4218 - loss: 1.6564 - val_accuracy: 0.4046 - val_loss: 1.6688
# Epoch 20/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.4330 - loss: 1.6353 - val_accuracy: 0.3772 - val_loss: 1.7498
# Epoch 21/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.4362 - loss: 1.6218 - val_accuracy: 0.4178 - val_loss: 1.6829
# Epoch 22/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.4467 - loss: 1.6014 - val_accuracy: 0.3898 - val_loss: 1.7070
# Epoch 23/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.4454 - loss: 1.5885 - val_accuracy: 0.4142 - val_loss: 1.6442
# Epoch 24/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.4524 - loss: 1.5675 - val_accuracy: 0.4365 - val_loss: 1.6051
# Epoch 25/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.4577 - loss: 1.5700 - val_accuracy: 0.4363 - val_loss: 1.5921
# Epoch 26/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.4590 - loss: 1.5592 - val_accuracy: 0.4269 - val_loss: 1.6088
# Epoch 27/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.
# Epoch 47/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.5724 - loss: 1.2270 - val_accuracy: 0.5221 - val_loss: 1.3460
# Epoch 48/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.5692 - loss: 1.2357 - val_accuracy: 0.4677 - val_loss: 1.5021
# Epoch 49/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - accuracy: 0.5690 - loss: 1.2338 - val_accuracy: 0.5210 - val_loss: 1.3783
# Epoch 50/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.5765 - loss: 1.2086 - val_accuracy: 0.5133 - val_loss: 1.3708

# %% [markdown]
# *   Compare the performance of both the models by plotting the loss and accuracy curves of both the training steps. Does the deeper model perform better? Comment on the observation.

# %%
plt.figure(figsize=(12,5))

plt.subplot(1,2,1)
plt.plot(history.history['accuracy'], 'b-', label='Shallow Train Acc')
plt.plot(history.history['val_accuracy'], 'b--', label='Shallow Val Acc')
plt.plot(history2.history['accuracy'], 'r-', label='Deep Train Acc')
plt.plot(history2.history['val_accuracy'], 'r--', label='Deep Val Acc')
plt.title('Training vs Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

# --- Loss comparison ---
plt.subplot(1,2,2)
plt.plot(history.history['loss'], 'b-', label='Shallow Train Loss')
plt.plot(history.history['val_loss'], 'b--', label='Shallow Val Loss')
plt.plot(history2.history['loss'], 'r-', label='Deep Train Loss')
plt.plot(history2.history['val_loss'], 'r--', label='Deep Val Loss')
plt.title('Training vs Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# **Comment on the observation**
#
# *(Double-click or enter to edit)*
#
# ...

# %% [markdown]
# *   Use predict function to predict the output for the test split
# *   Plot the confusion matrix for the new model and comment on the class confusions.

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
y_pred_probs = model.predict(x_test)
y_pred = np.argmax(y_pred_probs, axis=1)
y_true = np.argmax(y_test_onehot, axis=1)
cm = confusion_matrix(y_true, y_pred)

# Display confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=range(10))
plt.figure(figsize=(10,8))
disp.plot(cmap=plt.cm.Blues, values_format='d')
plt.title('Confusion Matrix for CIFAR-10')
plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step

# %% [markdown]
# **Comment here :**
#
# *(Double-click or enter to edit)*
#
# ...

# %% [markdown]
# *    Print the test accuracy for the trained model.

# %%
test_loss, test_accuracy = model.evaluate(x_test, y_test_onehot, verbose=1)

print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_accuracy:.4f}")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.5149 - loss: 1.3596
# Test Loss: 1.3613
# Test Accuracy: 0.5118

# %% [markdown]
# ## Define the complete VGG architecture.
#
# Stack two convolutional layers with 64 filters, each of 3 x 3 followed by max pooling layer.
#
# Stack two more convolutional layers with 128 filters, each of 3 x 3, followed by max pooling, followed by two more convolutional layers with 256 filters, each of 3 x 3, followed by max pooling.
#
# Flatten the output of the previous layer and add a dense layer with 128 units before the classification layer.
#
# For all the layers, use ReLU activation function.
#
# Use same padding for the layers to ensure that the height and width of each layer output matches the input
#
# *   Change the size of input to 64 x 64.

# %%
from keras.backend import clear_session
clear_session()

# %%
model3 = Sequential([
    Conv2D(64, (3,3), activation='relu', padding='same', input_shape=(64,64,3)),
    Conv2D(64, (3,3), activation='relu', padding='same'),
    MaxPooling2D(pool_size=(2,2)),
    Conv2D(128, (3,3), activation='relu', padding='same'),
    Conv2D(128, (3,3), activation='relu', padding='same'),
    MaxPooling2D(pool_size=(2,2)),
    Conv2D(256, (3,3), activation='relu', padding='same'),
    Conv2D(256, (3,3), activation='relu', padding='same'),
    MaxPooling2D(pool_size=(2,2)),
    Flatten(),
    Dense(128, activation='relu'),
    Dense(10, activation='softmax')
])

# %% [markdown]
# *   Compile the model using categorical_crossentropy loss, SGD optimizer and use 'accuracy' as the metric.
# *   Use the above defined model to train CIFAR-10 and train the model for 10 epochs with a batch size of 512.
# *   Predict the output for the test split and plot the confusion matrix for the new model and comment on the class confusions.

# %%
import tensorflow as tf
model3.compile(
    optimizer="sgd",
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# Resize images to 64x64
x_train_resized = tf.image.resize(x_train, (64, 64))
x_test_resized = tf.image.resize(x_test, (64, 64))
print(x_train_resized.shape)
history3 = model3.fit(
    x_train_resized, y_train_onehot,
    epochs=10,
    batch_size=512,
    validation_split=0.2
)
# Out:
# (50000, 64, 64, 3)
# Epoch 1/10
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 105s 741ms/step - accuracy: 0.6191 - loss: 1.0994 - val_accuracy: 0.5519 - val_loss: 1.2998
# Epoch 2/10
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 34s 426ms/step - accuracy: 0.6260 - loss: 1.0705 - val_accuracy: 0.5662 - val_loss: 1.2538
# Epoch 3/10
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 33s 419ms/step - accuracy: 0.6333 - loss: 1.0581 - val_accuracy: 0.5311 - val_loss: 1.3597
# Epoch 4/10
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 33s 424ms/step - accuracy: 0.6362 - loss: 1.0550 - val_accuracy: 0.5696 - val_loss: 1.2484
# Epoch 5/10
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 33s 423ms/step - accuracy: 0.6494 - loss: 1.0128 - val_accuracy: 0.5614 - val_loss: 1.3022
# Epoch 6/10
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 33s 422ms/step - accuracy: 0.6544 - loss: 0.9985 - val_accuracy: 0.5330 - val_loss: 1.3548
# Epoch 7/10
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 33s 421ms/step - accuracy: 0.6612 - loss: 0.9797 - val_accuracy: 0.5402 - val_loss: 1.3328
# Epoch 8/10
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 33s 421ms/step - accuracy: 0.6635 - loss: 0.9661 - val_accuracy: 0.5224 - val_loss: 1.4085
# Epoch 9/10
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 33s 423ms/step - accuracy: 0.6746 - loss: 0.9429 - val_accuracy: 0.5407 - val_loss: 1.3429
# Epoch 10/10
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 33s 422ms/step - accuracy: 0.6701 - loss: 0.9457 - val_accuracy: 0.5631 - val_loss: 1.3073

# %% [markdown]
# # Understanding deep networks
#
# *   What is the use of activation functions in network? Why is it needed?
# *   We have used softmax activation function in the exercise. There are other activation functions available too. What is the difference between sigmoid activation and softmax activation?
# *   What is the difference between categorical crossentropy and binary crossentropy loss?

# %% [markdown]
# **Write the answers below :**
#
# 1 - Use of activation functions:
#
# Activation functions are what make neural networks powerful and capable of learning complex, non-linear patterns
#
# _
#
# 2 - Key Differences between sigmoid and softmax:
#
# sigmoid use for binary output and softmax use for multiclass output and Converts logits to class probabilities
#
# _
#
# 3 - Key Differences between categorical crossentropy and binary crossentropy loss:
#
# binary crossentropy loss: used where each example belongs to one of two classes (0 or 1)
#
# categorical crossentropy: used where each example belongs to one of C classes (C > 2).
# _
